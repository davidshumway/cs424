# %%
data1 <- read.csv('data/Energy_Usage_2010.csv')#, check.names = FALSE)

# %%
# group by census block
# where "multiple" exist

# %%
library(mapview)
library(sf)
library(tigris)
library(leaflet)
options(tigris_use_cache = TRUE)
library(tidyr)

mapview(breweries)

#head(fips_codes)
#benton_bgs <- block_groups("Oregon", "Benton")
#plot(benton_bgs$geometry)

#rose_island <- blocks(state = "AS", county = "Rose Island")
cook <- blocks(state = "IL", county = "Cook", year=2010)

head(cook)
#head(data1)

nws <- subset(data1, COMMUNITY.AREA.NAME == "Near West Side")
y <- unique(nws[c('CENSUS.BLOCK')])
nrow(y)
# drop the total row
y <- y %>% drop_na()
nrow(y)


#print(y)
#head(nws)
#nrow(nws)
#nrow()
x <- subset(cook, TRACTCE10 == '833000')
x <- subset(cook, GEOID10 == '170318329001005')
x <- subset(cook, cook$GEOID10 %in% y$CENSUS.BLOCK)



#nrow(x)
#y <- st_sf(x, sf_column_name='geometry')

#c <- cook[cook$GEOID10 %in% nws["CENSUS.BLOCK"],]
#c<-mapView(subset(cook, TRACTCE10 == '833000'), xcol='INTPTLAT10', ycol='INTPTLON10')
#mapView(y)
#map


#c <- subset(cook, GEOID10 %in% nws["CENSUS.BLOCK"])
#head(c)
#nrow(c)
#nws["CENSUS.BLOCK"]

leaflet(x) %>%
  addTiles() %>%
  addPolygons()

# }

#a <- st_as_sf(data1['CENSUS BLOCK',])
#mapview(a)
# Out:
#   STATEFP10 COUNTYFP10 TRACTCE10 BLOCKCE10 GEOID10         NAME10     MTFCC10
# 1 17        031        804609    1014      170318046091014 Block 1014 G5040
# 2 17        031        823400    4046      170318234004046 Block 4046 G5040
# 3 17        031        822602    2022      170318226022022 Block 2022 G5040
# 4 17        031        823200    2032      170318232002032 Block 2032 G5040
# 5 17        031        823302    3013      170318233023013 Block 3013 G5040
# 6 17        031        823002    2010      170318230022010 Block 2010 G5040
#   UR10 UACE10 UATYP10 FUNCSTAT10 ALAND10 AWATER10 INTPTLAT10  INTPTLON10
# 1 U    16264  U       S           33492  0        +42.0353976 -088.0473272
# 2 U    16264  U       S           89552  0        +41.6635013 -087.7075362
# 3 U    16264  U       S           21019  0        +41.6990744 -087.7455270
# 4 U    16264  U       S          125368  0        +41.6629693 -087.7426862
# ...

# %%
library(mapview)
mapview(x)
mapview(franconia)
mapview(breweries, zcol = "founded", at = seq(1400, 2200, 200), legend = TRUE, verbose=TRUE)

mapviewOptions()
# Out:
#  global options:
#
# platform            : leaflet
# basemaps            : CartoDB.Positron CartoDB.DarkMatter OpenStreetMap Esri.WorldImagery OpenTopoMap
# raster.palette      : function (n)
# vector.palette      : function (n)
# verbose             : FALSE
# na.color            : #BEBEBE80
# legend              : TRUE
# legend.opacity      : 1
# legend.pos          : topright
# layers.control.pos  : topleft
# leafletWidth        :
# leafletHeight       :
# viewer.suppress     : FALSE
# homebutton          : TRUE
# homebutton.pos      : bottomright
# native.crs          : FALSE
# watch               : FALSE
# fgb                 : TRUE
#
#  raster data related options:
#
# raster.size         : 8388608
# mapview.maxpixels   : 5e+05
# plainview.maxpixels : 1e+07
# use.layer.names     : FALSE
# trim                : TRUE
# method              : bilinear
# query.type          : mousemove
# query.digits        : 7
# query.position      : topright
# query.prefix        : Layer
#
# ...
